# %%
import pandas as pd
import numpy as np
from sklearn.preprocessing import MinMaxScaler

try:
    df = pd.read_csv("df_final.csv")
except FileNotFoundError:
    exit()

df.head()
# Out:
#    cod_municipio          municipio   latitud  longitud    altitud  poblacion  \
# 0             14       Acebeda (La)  41.08697 -3.624634  1266.5420       68.0
# 1             29            Ajalvir  40.53437 -3.481002   680.1722     4946.0
# 2             35  Alameda del Valle  40.91790 -3.843788  1109.9340      256.0
# 3             40         Álamo (El)  40.22972 -3.992688   606.2238    10413.0
# 4             88   Aldea del Fresno  40.32399 -4.202217   476.7994     3422.0
#
#    centros_salud_10mil  farmacias_10mil  latitud_google_places  \
# 0                    0                0               41.08697
# 1                    0                2               40.53437
# 2                    0               39               40.91790
# 3                    0                2               40.22972
# 4                    0                3               40.32399
#
#    longitud_google_places  ...  afiliados_agricultura_y_ganadería  \
# 0               -3.624634  ...                                  0
# 1               -3.481002  ...                                 15
# 2               -3.843788  ...                                  4
# 3               -3.992688  ...                                 22
# 4               -4.202217  ...                                 27
#
#    afiliados_construcción  afiliados_minería_industria_y_energía  \
# 0                       1                                      2
# 1                     110                                    253
# 2                       3                                      4
# 3                     371                                    319
# 4                     149                                     70
#
#    afiliados_otros_servicios  afiliados_servicios_a_empresas_y_financieros  \
# 0                          8                                             8
# 1                        578                                           521
# 2                         31                                            20
# 3                       1164                                           773
# 4                        340                                           213
#
#    afiliados_servicios_de_distribución_y_hostelería  afiliados_total  \
# 0                                                11               30
# 1                                               691             2168
# 2                                                27               89
# 3                                              1122             3771
# 4                                               283             1082
#
#    alumnos_total  cultura  IPVA
# 0              0      0.0   NaN
# 1           1336      0.0   NaN
# 2              0      0.0   NaN
# 3           4244      0.0   NaN
# 4            566      0.0   NaN
#
# [5 rows x 64 columns]

# %%
if 'IPVA' in df.columns:
    df = df.drop(columns=['IPVA'])
else:
    print("Column 'IPVA' does not exist in the DataFrame.")

# positive variables
positive_vars = [
    "centros_salud_10mil", "farmacias_10mil",
    "n_gym", "gym_weighted_avg_rating",
    "n_restaurant",  "restaurant_weighted_avg_rating",
    "n_pharmacy",  "pharmacy_weighted_avg_rating",
    "n_school",  "school_weighted_avg_rating",
    "n_transport","transport_weighted_avg_rating",
    "afiliados_agricultura_y_ganadería", "afiliados_construcción",
    "afiliados_minería_industria_y_energía", "afiliados_otros_servicios",
    "afiliados_servicios_a_empresas_y_financieros",
    "afiliados_servicios_de_distribución_y_hostelería",
    "afiliados_total", "alumnos_total", "cultura",
]
# negative variables
negative_vars = ["paro_total", "paro_100", "distancia_capital"]

scaler = MinMaxScaler()

# %%
def commute_score(x):
    if pd.isna(x):
        return None
    if x < 30:
        return 1
    elif x <= 60:
        return 0.5
    else:
        return 0
    
df['commute_score'] = df['distancia_capital'].apply(commute_score)
positive_vars += ["commute_score"]
df['restaurant_total_reviews'] = np.log1p(df['restaurant_total_reviews']) 
df['gym_total_reviews'] = np.log1p(df['gym_total_reviews']) 
df['school_total_reviews'] = np.log1p(df['school_total_reviews']) 
df['pharmacy_total_reviews'] = np.log1p(df['pharmacy_total_reviews']) 
df['transport_total_reviews'] = np.log1p(df['transport_total_reviews'])

# %%
df_scaled = df.copy()

# scale all variables to [0, 1]
df_scaled[positive_vars + negative_vars] = scaler.fit_transform(
    df[positive_vars + negative_vars]
)

# invert negative variables
df_scaled[negative_vars] = 1 - df_scaled[negative_vars]
df_scaled.head(3)
# Out:
#    cod_municipio          municipio   latitud  longitud    altitud  poblacion  \
# 0             14       Acebeda (La)  41.08697 -3.624634  1266.5420       68.0
# 1             29            Ajalvir  40.53437 -3.481002   680.1722     4946.0
# 2             35  Alameda del Valle  40.91790 -3.843788  1109.9340      256.0
#
#    centros_salud_10mil  farmacias_10mil  latitud_google_places  \
# 0                  0.0             0.00               41.08697
# 1                  0.0             0.04               40.53437
# 2                  0.0             0.78               40.91790
#
#    longitud_google_places  ...  afiliados_agricultura_y_ganadería  \
# 0               -3.624634  ...                           0.000000
# 1               -3.481002  ...                           0.064655
# 2               -3.843788  ...                           0.017241
#
#    afiliados_construcción  afiliados_minería_industria_y_energía  \
# 0                0.000733                               0.001106
# 1                0.080645                               0.139856
# 2                0.002199                               0.002211
#
#    afiliados_otros_servicios  afiliados_servicios_a_empresas_y_financieros  \
# 0                   0.001047                                      0.001368
# 1                   0.100506                                      0.101642
# 2                   0.005060                                      0.003714
#
#    afiliados_servicios_de_distribución_y_hostelería  afiliados_total  \
# 0                                          0.001060         0.001065
# 1                                          0.104012         0.109522
# 2                                          0.003482         0.004058
#
#    alumnos_total  cultura  commute_score
# 0       0.000000      0.0            0.0
# 1       0.035199      0.0            0.5
# 2       0.000000      0.0            0.0
#
# [3 rows x 64 columns]

# %% [markdown]
# Weights are chosen based on personal belief of importance.

# %%
categories = { 
    "salud": ["centros_salud_10mil", 
              "farmacias_10mil", 
              "n_pharmacy", 
              "pharmacy_weighted_avg_rating"], 
    "educacion": ["school_weighted_avg_rating",
                   "n_school", 
                   "alumnos_total"], 
    "cultural": ["cultura",
                 "n_gym", 
                 "gym_weighted_avg_rating",
                 "n_restaurant", 
                 "restaurant_weighted_avg_rating"], 
    "transporte": ["commute_score"], 
    "calidad_vida":["paro_100", 
                    "afiliados_total",] }
category_weights = {
    "salud": {
        "centros_salud_10mil": 0.4,
        "farmacias_10mil": 0.3,
        "n_pharmacy": 0.1,
        "pharmacy_weighted_avg_rating": 0.2
    },
    "educacion": {
        "school_weighted_avg_rating": 0.5,
        "n_school": 0.3,
        "alumnos_total": 0.2
    },
    "cultural": {
        "cultura": 0.3,
        "n_gym": 0.15,
        "gym_weighted_avg_rating": 0.2,
        "n_restaurant": 0.15,
        "restaurant_weighted_avg_rating": 0.2
    },
    "transporte": {
        "commute_score": 1.0
    },
    "calidad_vida": {
        "paro_100": 0.6,
        "afiliados_total": 0.4
    }
}

# %%
category_indices = pd.DataFrame(index=df_scaled.index)
for category, vars in categories.items():
    weights = category_weights[category]
    category_indices[category] = (
    pd.concat([df_scaled[var] * weights[var] for var in vars], axis=1)
    .sum(axis=1)
)

# %%
category_indices.head(3)
# Out:
#       salud  educacion  cultural  transporte  calidad_vida
# 0  0.205000   0.545000  0.190537         0.0      0.450426
# 1  0.244370   0.766337  0.556492         0.5      0.413636
# 2  0.377813   0.465000  0.302021         0.0      0.434382

# %%
df_final_joined = pd.concat([df_scaled[['cod_municipio', 'municipio', 'latitud', 'longitud', 'altitud']], category_indices], axis=1)
df_final_joined['overall_index'] = category_indices.mean(axis=1)
df_final_joined.head(3)
# Out:
#    cod_municipio          municipio   latitud  longitud    altitud     salud  \
# 0             14       Acebeda (La)  41.08697 -3.624634  1266.5420  0.205000
# 1             29            Ajalvir  40.53437 -3.481002   680.1722  0.244370
# 2             35  Alameda del Valle  40.91790 -3.843788  1109.9340  0.377813
#
#    educacion  cultural  transporte  calidad_vida  overall_index
# 0   0.545000  0.190537         0.0      0.450426       0.278193
# 1   0.766337  0.556492         0.5      0.413636       0.496167
# 2   0.465000  0.302021         0.0      0.434382       0.315843
